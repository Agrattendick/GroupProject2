# %%
## Imports
# Dependencies and Setup
import pandas as pd
import numpy as np
import datetime, json, requests, time, csv
from pandas.io.json import json_normalize

# %%
#### Google Places API text search
#### {store} in {state}
####
#### https://maps.googleapis.com/maps/api/place/textsearch/json?query=Target+in+MO&key=AIzaSyBTygt0iTuAHmp5A-BYjE_byAROQ_E5y0M

# %%
## Google Places API 
google_api_url = "https://maps.googleapis.com/maps/api/place/textsearch/json?query={}+in+{}&key=AIzaSyAav9-7IXlau7ObnUrVHerk39REwQzNvHI"

# %%
states = ["AL","AK","AZ","AR","CA","CO","CT","DE","DC","FL","GA","HI","ID","IL","IN","IA","KS","KY","LA","ME","MD","MA","MI","MN","MS","MO","MT","NE","NV","NH","NJ","NM","NY","NC","ND","OH","OK","OR","PA","RI","SC","SD","TN","TX","UT","VT","VA","WA","WV","WI","WY"]

# %%
'''
## Functions
-------------------------------------------------
'''
def current_date_timestamp():
    return time.strftime('%Y-%m-%d-%H.%M.%S')

def get_geo(state, store):
    url = google_api_url.format(store, state)
    print('Calling Google API: {}'.format(url))

    resp = requests.get(url).json()
    result = json_normalize(resp['results'])
   
    return result

# %%
# output file -- current datestamp
# makes unique name
csv_file = "ben&jerrys.geo-loc.{}.csv".format(current_date_timestamp())

# store all the goods
summary_df = pd.DataFrame()

# %%
# list of states, stores
lstates = ["AL","AZ","AR","CA","CO","CT","DE","DC","FL","GA","ID","IL","IN","IA","KS","KY","LA","ME","MD","MA","MI","MN","MS","MO","MT","NE","NV","NH","NJ","NM","NY","NC","ND","OH","OK","OR","PA","RI","SC","SD","TN","TX","UT","VT","VA","WA","WV","WI","WY"]
lstores = ["Ben and Jerry's"] ## <<<< must be a list

# %%
print('Mapster: START ##########################')
# Out:
# Mapster: START ##########################

# %%
# loop thru list of stores
for store in lstores:
    print('Getting lat(s)/log(s) for : {}'.format(store))

    for state in lstates:
        print('Feteching geo data [state]: {}'.format(state))

        # calls Google API function
        # JSON output puting in dataframe; Pandas is nice
        geo_result = get_geo(state, store)
        df = pd.DataFrame(geo_result)
        print('Result DataFrame length   : {}'.format(len(df)))

        # moves on if there are not results from search
        if len(df) > 0:
            df['bfa.store'] = store
            df['bfa.state'] = state

            geo_df = pd.DataFrame(df[['bfa.store', 'bfa.state', 'place_id', 'name', 'formatted_address', 'geometry.location.lat', 'geometry.location.lng']])
            print('Geo data DataFrame shape  : {}'.format(df.shape))

            summary_df = pd.concat([summary_df, geo_df])
            print('Summary data frame shape  : {}'.format(summary_df.shape))

print('Final summary geo DataFrame {}'.format(summary_df.info()))
# Out:
# Getting lat(s)/log(s) for : Ben and Jerry's
# Feteching geo data [state]: AL
# Calling Google API: https://maps.googleapis.com/maps/api/place/textsearch/json?query=Ben and Jerry's+in+AL&key=AIzaSyAav9-7IXlau7ObnUrVHerk39REwQzNvHI
# Result DataFrame length   : 7
# Geo data DataFrame shape  : (7, 22)
# Summary data frame shape  : (7, 7)
# Feteching geo data [state]: AZ
# Calling Google API: https://maps.googleapis.com/maps/api/place/textsearch/json?query=Ben and Jerry's+in+AZ&key=AIzaSyAav9-7IXlau7ObnUrVHerk39REwQzNvHI
# Result DataFrame length   : 7
# Geo data DataFrame shape  : (7, 22)
# Summary data frame shape  : (14, 7)
# Feteching geo data [state]: AR
# Calling Google API: https://maps.googleapis.com/maps/api/place/textsearch/json?query=Ben and Jerry's+in+AR&key=AIzaSyAav9-7IXlau7ObnUrVHerk39REwQzNvHI
# Result DataFrame length   : 1
# Geo data DataFrame shape  : (1, 21)
# Summary data frame shape  : (15, 7)
# Feteching geo data [state]: CA
# Calling Google API: https://maps.googleapis.com/maps/api/place/textsearch/json?query=Ben and Jerry's+in+CA&key=AIzaSyAav9-7IXlau7ObnUrVHerk39REwQzNvHI
# Result DataFrame length   : 20
# Geo data DataFrame shape  : (20, 21)
# Summary data frame shape  : (35, 7)
# Feteching geo data [state]: CO
# Calling Google API: https://maps.googleapis.com/maps/api/place/textsearch/json?query=Ben and Jerry's+in+CO&key=AIzaSyAav9-7IXlau7ObnUrVHerk39REwQzNvHI
# Result DataFrame length   : 6
# Geo data DataFrame shape  : (6, 21)
# Summary data frame shape  : (41, 7)
# Feteching geo data [state]: CT
# Calling Google API: https://maps.googleapis.com/maps/api/place/textsearch/json?query=Ben and Jerry's+in+CT&key=AIzaSyAav9-7IXlau7ObnUrVHerk39REwQzNvHI
# Result DataFrame length   : 9
# Geo data DataFrame shape  : (9, 21)
# Summary data frame shape  : (50, 7)
# Feteching geo data [state]: DE
# Calling Google API: https://maps.googleapis.com/maps/api/place/textsearch/json?query=Ben and Jerry's+in+DE&key=AIzaSyAav9-7IXlau7ObnUrVHerk39REwQzNvHI
# Result DataFrame length   : 0
# Feteching geo data [state]: DC
# Calling Google API: https://maps.googleapis.com/maps/api/place/textsearch/json?query=Ben and Jerry's+in+DC&key=AIzaSyAav9-7IXlau7ObnUrVHerk39REwQzNvHI
# Result DataFrame length   : 2
# Geo data DataFrame shape  : (2, 21)
# Summary data frame shape  : (52, 7)
# Feteching geo data [state]: FL
# Calling Google API: https://maps.googleapis.com/maps/api/place/textsearch/json?query=Ben and Jerry's+in+FL&key=AIzaSyAav9-7IXlau7ObnUrVHerk39REwQzNvHI
# Result DataFrame length   : 20
# Geo data DataFrame shape  : (20, 21)
# Summary data frame shape  : (72, 7)
# Feteching geo data [state]: GA
# Calling Google API: https://maps.googleapis.com/maps/api/place/textsearch/json?query=Ben and Jerry's+in+GA&key=AIzaSyAav9-7IXlau7ObnUrVHerk39REwQzNvHI
# Result DataFrame length   : 3
# Geo data DataFrame shape  : (3, 21)
# Summary data frame shape  : (75, 7)
# Feteching geo data [state]: ID
# Calling Google API: https://maps.googleapis.com/maps/api/place/textsearch/json?query=Ben and Jerry's+in+ID&key=AIzaSyAav9-7IXlau7ObnUrVHerk39REwQzNvHI
# Result DataFrame length   : 1
# Geo data DataFrame shape  : (1, 21)
# Summary data frame shape  : (76, 7)
# Feteching geo data [state]: IL
# Calling Google API: https://maps.googleapis.com/maps/api/place/textsearch/json?query=Ben and Jerry's+in+IL&key=AIzaSyAav9-7IXlau7ObnUrVHerk39REwQzNvHI
# Result DataFrame length   : 2
# Geo data DataFrame shape  : (2, 21)
# Summary data frame shape  : (78, 7)
# Feteching geo data [state]: IN
# Calling Google API: https://maps.googleapis.com/maps/api/place/textsearch/json?query=Ben and Jerry's+in+IN&key=AIzaSyAav9-7IXlau7ObnUrVHerk39REwQzNvHI
# Result DataFrame length   : 0
# Feteching geo data [state]: IA
# Calling Google API: https://maps.googleapis.com/maps/api/place/textsearch/json?query=Ben and Jerry's+in+IA&key=AIzaSyAav9-7IXlau7ObnUrVHerk39REwQzNvHI
# Result DataFrame length   : 2
# Geo data DataFrame shape  : (2, 20)
# Summary data frame shape  : (80, 7)
# Feteching geo data [state]: KS
# Calling Google API: https://maps.googleapis.com/maps/api/place/textsearch/json?query=Ben and Jerry's+in+KS&key=AIzaSyAav9-7IXlau7ObnUrVHerk39REwQzNvHI
# Result DataFrame length   : 1
# Geo data DataFrame shape  : (1, 20)
# Summary data frame shape  : (81, 7)
# Feteching geo data [state]: KY
# Calling Google API: https://maps.googleapis.com/maps/api/place/textsearch/json?query=Ben and Jerry's+in+KY&key=AIzaSyAav9-7IXlau7ObnUrVHerk39REwQzNvHI
# Result DataFrame length   : 6
# Geo data DataFrame shape  : (6, 22)
# Summary data frame shape  : (87, 7)
# Feteching geo data [state]: LA
# Calling Google API: https://maps.googleapis.com/maps/api/place/textsearch/json?query=Ben and Jerry's+in+LA&key=AIzaSyAav9-7IXlau7ObnUrVHerk39REwQzNvHI
# Result DataFrame length   : 4
# Geo data DataFrame shape  : (4, 21)
# Summary data frame shape  : (91, 7)
# Feteching geo data [state]: ME
# Calling Google API: https://maps.googleapis.com/maps/api/place/textsearch/json?query=Ben and Jerry's+in+ME&key=AIzaSyAav9-7IXlau7ObnUrVHerk39REwQzNvHI
# Result DataFrame length   : 0
# Feteching geo data [state]: MD
# Calling Google API: https://maps.googleapis.com/maps/api/place/textsearch/json?query=Ben and Jerry's+in+MD&key=AIzaSyAav9-7IXlau7ObnUrVHerk39REwQzNvHI
# Result DataFrame length   : 3
# Geo data DataFrame shape  : (3, 21)
# Summary data frame shape  : (94, 7)
# Feteching geo data [state]: MA
# Calling Google API: https://maps.googleapis.com/maps/api/place/textsearch/json?query=Ben and Jerry's+in+MA&key=AIzaSyAav9-7IXlau7ObnUrVHerk39REwQzNvHI
# Result DataFrame length   : 15
# Geo data DataFrame shape  : (15, 21)
# Summary data frame shape  : (109, 7)
# Feteching geo data [state]: MI
# Calling Google API: https://maps.googleapis.com/maps/api/place/textsearch/json?query=Ben and Jerry's+in+MI&key=AIzaSyAav9-7IXlau7ObnUrVHerk39REwQzNvHI
# Result DataFrame length   : 2
# Geo data DataFrame shape  : (2, 22)
# Summary data frame shape  : (111, 7)
# Feteching geo data [state]: MN
# Calling Google API: https://maps.googleapis.com/maps/api/place/textsearch/json?query=Ben and Jerry's+in+MN&key=AIzaSyAav9-7IXlau7ObnUrVHerk39REwQzNvHI
# Result DataFrame length   : 2
# Geo data DataFrame shape  : (2, 21)
# Summary data frame shape  : (113, 7)
# Feteching geo data [state]: MS
# Calling Google API: https://maps.googleapis.com/maps/api/place/textsearch/json?query=Ben and Jerry's+in+MS&key=AIzaSyAav9-7IXlau7ObnUrVHerk39REwQzNvHI
# Result DataFrame length   : 1
# Geo data DataFrame shape  : (1, 21)
# Summary data frame shape  : (114, 7)
# Feteching geo data [state]: MO
# Calling Google API: https://maps.googleapis.com/maps/api/place/textsearch/json?query=Ben and Jerry's+in+MO&key=AIzaSyAav9-7IXlau7ObnUrVHerk39REwQzNvHI
# Result DataFrame length   : 1
# Geo data DataFrame shape  : (1, 21)
# Summary data frame shape  : (115, 7)
# Feteching geo data [state]: MT
# Calling Google API: https://maps.googleapis.com/maps/api/place/textsearch/json?query=Ben and Jerry's+in+MT&key=AIzaSyAav9-7IXlau7ObnUrVHerk39REwQzNvHI
# Result DataFrame length   : 1
# Geo data DataFrame shape  : (1, 21)
# Summary data frame shape  : (116, 7)
# Feteching geo data [state]: NE
# Calling Google API: https://maps.googleapis.com/maps/api/place/textsearch/json?query=Ben and Jerry's+in+NE&key=AIzaSyAav9-7IXlau7ObnUrVHerk39REwQzNvHI
# Result DataFrame length   : 8
# Geo data DataFrame shape  : (8, 21)
# Summary data frame shape  : (124, 7)
# Feteching geo data [state]: NV
# Calling Google API: https://maps.googleapis.com/maps/api/place/textsearch/json?query=Ben and Jerry's+in+NV&key=AIzaSyAav9-7IXlau7ObnUrVHerk39REwQzNvHI
# Result DataFrame length   : 5
# Geo data DataFrame shape  : (5, 21)
# Summary data frame shape  : (129, 7)
# Feteching geo data [state]: NH
# Calling Google API: https://maps.googleapis.com/maps/api/place/textsearch/json?query=Ben and Jerry's+in+NH&key=AIzaSyAav9-7IXlau7ObnUrVHerk39REwQzNvHI
# Result DataFrame length   : 3
# Geo data DataFrame shape  : (3, 21)
# Summary data frame shape  : (132, 7)
# Feteching geo data [state]: NJ
# Calling Google API: https://maps.googleapis.com/maps/api/place/textsearch/json?query=Ben and Jerry's+in+NJ&key=AIzaSyAav9-7IXlau7ObnUrVHerk39REwQzNvHI
# Result DataFrame length   : 11
# Geo data DataFrame shape  : (11, 21)
# Summary data frame shape  : (143, 7)
# Feteching geo data [state]: NM
# Calling Google API: https://maps.googleapis.com/maps/api/place/textsearch/json?query=Ben and Jerry's+in+NM&key=AIzaSyAav9-7IXlau7ObnUrVHerk39REwQzNvHI
# Result DataFrame length   : 2
# Geo data DataFrame shape  : (2, 22)
# Summary data frame shape  : (145, 7)
# Feteching geo data [state]: NY
# Calling Google API: https://maps.googleapis.com/maps/api/place/textsearch/json?query=Ben and Jerry's+in+NY&key=AIzaSyAav9-7IXlau7ObnUrVHerk39REwQzNvHI
# Result DataFrame length   : 14
# Geo data DataFrame shape  : (14, 21)
# Summary data frame shape  : (159, 7)
# Feteching geo data [state]: NC
# Calling Google API: https://maps.googleapis.com/maps/api/place/textsearch/json?query=Ben and Jerry's+in+NC&key=AIzaSyAav9-7IXlau7ObnUrVHerk39REwQzNvHI
# Result DataFrame length   : 15
# Geo data DataFrame shape  : (15, 21)
# Summary data frame shape  : (174, 7)
# Feteching geo data [state]: ND
# Calling Google API: https://maps.googleapis.com/maps/api/place/textsearch/json?query=Ben and Jerry's+in+ND&key=AIzaSyAav9-7IXlau7ObnUrVHerk39REwQzNvHI
# Result DataFrame length   : 0
# Feteching geo data [state]: OH
# Calling Google API: https://maps.googleapis.com/maps/api/place/textsearch/json?query=Ben and Jerry's+in+OH&key=AIzaSyAav9-7IXlau7ObnUrVHerk39REwQzNvHI
# Result DataFrame length   : 2
# Geo data DataFrame shape  : (2, 21)
# Summary data frame shape  : (176, 7)
# Feteching geo data [state]: OK
# Calling Google API: https://maps.googleapis.com/maps/api/place/textsearch/json?query=Ben and Jerry's+in+OK&key=AIzaSyAav9-7IXlau7ObnUrVHerk39REwQzNvHI
# Result DataFrame length   : 4
# Geo data DataFrame shape  : (4, 22)
# Summary data frame shape  : (180, 7)
# Feteching geo data [state]: OR
# Calling Google API: https://maps.googleapis.com/maps/api/place/textsearch/json?query=Ben and Jerry's+in+OR&key=AIzaSyAav9-7IXlau7ObnUrVHerk39REwQzNvHI
# Result DataFrame length   : 0
# Feteching geo data [state]: PA
# Calling Google API: https://maps.googleapis.com/maps/api/place/textsearch/json?query=Ben and Jerry's+in+PA&key=AIzaSyAav9-7IXlau7ObnUrVHerk39REwQzNvHI
# Result DataFrame length   : 3
# Geo data DataFrame shape  : (3, 21)
# Summary data frame shape  : (183, 7)
# Feteching geo data [state]: RI
# Calling Google API: https://maps.googleapis.com/maps/api/place/textsearch/json?query=Ben and Jerry's+in+RI&key=AIzaSyAav9-7IXlau7ObnUrVHerk39REwQzNvHI
# Result DataFrame length   : 4
# Geo data DataFrame shape  : (4, 21)
# Summary data frame shape  : (187, 7)
# Feteching geo data [state]: SC
# Calling Google API: https://maps.googleapis.com/maps/api/place/textsearch/json?query=Ben and Jerry's+in+SC&key=AIzaSyAav9-7IXlau7ObnUrVHerk39REwQzNvHI
# Result DataFrame length   : 9
# Geo data DataFrame shape  : (9, 21)
# Summary data frame shape  : (196, 7)
# Feteching geo data [state]: SD
# Calling Google API: https://maps.googleapis.com/maps/api/place/textsearch/json?query=Ben and Jerry's+in+SD&key=AIzaSyAav9-7IXlau7ObnUrVHerk39REwQzNvHI
# Result DataFrame length   : 1
# Geo data DataFrame shape  : (1, 21)
# Summary data frame shape  : (197, 7)
# Feteching geo data [state]: TN
# Calling Google API: https://maps.googleapis.com/maps/api/place/textsearch/json?query=Ben and Jerry's+in+TN&key=AIzaSyAav9-7IXlau7ObnUrVHerk39REwQzNvHI
# Result DataFrame length   : 6
# Geo data DataFrame shape  : (6, 21)
# Summary data frame shape  : (203, 7)
# Feteching geo data [state]: TX
# Calling Google API: https://maps.googleapis.com/maps/api/place/textsearch/json?query=Ben and Jerry's+in+TX&key=AIzaSyAav9-7IXlau7ObnUrVHerk39REwQzNvHI
# Result DataFrame length   : 7
# Geo data DataFrame shape  : (7, 21)
# Summary data frame shape  : (210, 7)
# Feteching geo data [state]: UT
# Calling Google API: https://maps.googleapis.com/maps/api/place/textsearch/json?query=Ben and Jerry's+in+UT&key=AIzaSyAav9-7IXlau7ObnUrVHerk39REwQzNvHI
# Result DataFrame length   : 5
# Geo data DataFrame shape  : (5, 22)
# Summary data frame shape  : (215, 7)
# Feteching geo data [state]: VT
# Calling Google API: https://maps.googleapis.com/maps/api/place/textsearch/json?query=Ben and Jerry's+in+VT&key=AIzaSyAav9-7IXlau7ObnUrVHerk39REwQzNvHI
# Result DataFrame length   : 4
# Geo data DataFrame shape  : (4, 21)
# Summary data frame shape  : (219, 7)
# Feteching geo data [state]: VA
# Calling Google API: https://maps.googleapis.com/maps/api/place/textsearch/json?query=Ben and Jerry's+in+VA&key=AIzaSyAav9-7IXlau7ObnUrVHerk39REwQzNvHI
# Result DataFrame length   : 13
# Geo data DataFrame shape  : (13, 21)
# Summary data frame shape  : (232, 7)
# Feteching geo data [state]: WA
# Calling Google API: https://maps.googleapis.com/maps/api/place/textsearch/json?query=Ben and Jerry's+in+WA&key=AIzaSyAav9-7IXlau7ObnUrVHerk39REwQzNvHI
# Result DataFrame length   : 4
# Geo data DataFrame shape  : (4, 21)
# Summary data frame shape  : (236, 7)
# Feteching geo data [state]: WV
# Calling Google API: https://maps.googleapis.com/maps/api/place/textsearch/json?query=Ben and Jerry's+in+WV&key=AIzaSyAav9-7IXlau7ObnUrVHerk39REwQzNvHI
# Result DataFrame length   : 2
# Geo data DataFrame shape  : (2, 21)
# Summary data frame shape  : (238, 7)
# Feteching geo data [state]: WI
# Calling Google API: https://maps.googleapis.com/maps/api/place/textsearch/json?query=Ben and Jerry's+in+WI&key=AIzaSyAav9-7IXlau7ObnUrVHerk39REwQzNvHI
# Result DataFrame length   : 8
# Geo data DataFrame shape  : (8, 22)
# Summary data frame shape  : (246, 7)
# Feteching geo data [state]: WY
# Calling Google API: https://maps.googleapis.com/maps/api/place/textsearch/json?query=Ben and Jerry's+in+WY&key=AIzaSyAav9-7IXlau7ObnUrVHerk39REwQzNvHI
# Result DataFrame length   : 1
# Geo data DataFrame shape  : (1, 21)
# Summary data frame shape  : (247, 7)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 247 entries, 0 to 0
# Data columns (total 7 columns):
# bfa.store                247 non-null object
# bfa.state                247 non-null object
# place_id                 247 non-null object
# name                     247 non-null object
# formatted_address        247 non-null object
# geometry.location.lat    247 non-null float64
# geometry.location.lng    247 non-null float64
# dtypes: float64(2), object(5)
# memory usage: 15.4+ KB
# Final summary geo DataFrame None

# %%
icecream_df = summary_df.rename(index=str, columns={'bfa.store':'store', 'bfa.state':'state', 'place_id':'place_id', 'name':'name', 'formatted_address':'address', 'geometry.location.lat':'latitude', 'geometry.location.lng':'longitude'})
icecream_df
# Out:
#               store state                     place_id  \
# 0   Ben and Jerry's    AL  ChIJkardCvVXi4gRFHu9ZF7L6AU
# 1   Ben and Jerry's    AL  ChIJ0_QqoGFeYIgRgMuLlElAKW8
# 2   Ben and Jerry's    AL  ChIJJZ0n6XdtmogREku-OG-Ek1I
# 3   Ben and Jerry's    AL  ChIJH_86bKpNmogR4g33-vp6ttU
# 4   Ben and Jerry's    AL  ChIJc1Wj0KNsYogRoJUhcAJrr-Q
# 5   Ben and Jerry's    AL  ChIJMTPlSlFZkYgRroYG22B5YCI
# 6   Ben and Jerry's    AL  ChIJGXOkbrZsYogR4I5fR5x5HH8
# 0   Ben and Jerry's    AZ  ChIJNRRNoN3RyIAR8-HZluDBkxU
# 1   Ben and Jerry's    AZ  ChIJsQ41Vp0TK4cR7kVAZLoeaQE
# 2   Ben and Jerry's    AZ  ChIJz2VuS3UVK4cRw07Nmh05xMU
# 3   Ben and Jerry's    AZ  ChIJTRJlLPHQyIAR5THux6fPoDQ
# 4   Ben and Jerry's    AZ  ChIJ7ZRhFTrEyIARn1A0skICWiQ
# 5   Ben and Jerry's    AZ  ChIJuaZNPhbEyIAR__jh3U-BJW8
# 6   Ben and Jerry's    AZ  ChIJj_6e8Th5K4cRWqpGCbempb4
# 0   Ben and Jerry's    AR  ChIJ-z2K32SEf4gR9QGZ-fj6w7s
# 0   Ben and Jerry's    CA  ChIJleyQQ9wt3YARX-CgzLMtfxM
# 1   Ben and Jerry's    CA  ChIJucLtwJ1-hYAR-qBdBl0deFo
# 2   Ben and Jerry's    CA  ChIJXYFfDmcGhYARfr3P826YBUI
# 3   Ben and Jerry's    CA  ChIJFZZwZR_c3IARNwGk1Bug0WM
# 4   Ben and Jerry's    CA  ChIJsbMzM1OHhYAR-htwK_E89Ro
# 5   Ben and Jerry's    CA  ChIJjZU1UETGwoARoYR4Acs4kWA
# 6   Ben and Jerry's    CA  ChIJARFaMY-AhYARd8OnSIZOwUQ
# 7   Ben and Jerry's    CA  ChIJpxDCnk6-woARs1gTwqh2594
# 8   Ben and Jerry's    CA  ChIJX7X1sHSbwoARlJVoK22v7H4
# 9   Ben and Jerry's    CA  ChIJgxtI__L92oARZzKb35MhyqU
# 10  Ben and Jerry's    CA  ChIJP_m8OPCs6YARp2Qbk7-555E
# 11  Ben and Jerry's    CA  ChIJTdTix5SXwoARMcRpABpAG3E
# 12  Ben and Jerry's    CA  ChIJ9_XeO023woARGOwoi09IVDg
# 13  Ben and Jerry's    CA  ChIJ6Y5xrqUb24ARsAM8N7KIxGI
# 14  Ben and Jerry's    CA  ChIJmw1DtxOHwoARQ1JhbgUVHxw
# ..              ...   ...                          ...
# 2   Ben and Jerry's    VT  ChIJmf--YFBe4IkR-O621d0dIQo
# 3   Ben and Jerry's    VT  ChIJqdfmQEyNtUwRL9NARyIKJwI
# 0   Ben and Jerry's    VA  ChIJT1mEn3HpuokRxl0GvlNWCCI
# 1   Ben and Jerry's    VA  ChIJDdp-LJnpuokRyHoyQtCd9Ig
# 2   Ben and Jerry's    VA  ChIJDZIxHvawt4kR5AmKCQXJLUI
# 3   Ben and Jerry's    VA  ChIJWSyHuWpPtokRzulfiwRSdwc
# 4   Ben and Jerry's    VA  ChIJ_6IKe7aHs4kRDe6xqIYM7Pc
# 5   Ben and Jerry's    VA  ChIJLQwbH2_puokRSHg40YgXEZU
# 6   Ben and Jerry's    VA  ChIJwdGAGB9ItokRYNk7JFRjRhg
# 7   Ben and Jerry's    VA  ChIJZ0d48J85tokRHEwp-XYePJE
# 8   Ben and Jerry's    VA  ChIJp80zAn0OTYgRTtKhsE3zjoU
# 9   Ben and Jerry's    VA  ChIJs0vKHwjDuokRt-Clw6HonTo
# 10  Ben and Jerry's    VA  ChIJsZn-BmGTTYgR8ByoqGagqq8
# 11  Ben and Jerry's    VA  ChIJ-3W-NhGNsIkRyf7Ah2qRtvE
# 12  Ben and Jerry's    VA  ChIJ2fUTC_uAsIkRPyDFJr2DNcA
# 0   Ben and Jerry's    WA  ChIJSWywlHqhMioRlV9BndfT0Fw
# 1   Ben and Jerry's    WA  ChIJ0VwP4pCrMioR10Q1asipOlo
# 2   Ben and Jerry's    WA  ChIJjyM3cNG6MioRkoAZvLrr5lM
# 3   Ben and Jerry's    WA  ChIJ3f13E11TzSsRaf-aUD3EUL8
# 0   Ben and Jerry's    WV  ChIJsZn-BmGTTYgR8ByoqGagqq8
# 1   Ben and Jerry's    WV  ChIJZ0d48J85tokRHEwp-XYePJE
# 0   Ben and Jerry's    WI  ChIJJyGFwK_HD4gRtZUkmFN3zk8
# 1   Ben and Jerry's    WI  ChIJj3c_ZFIrDogR4OxvPsmW4C8
# 2   Ben and Jerry's    WI  ChIJdZPu822dBIgRf4zD23JG9w4
# 3   Ben and Jerry's    WI  ChIJR7mcJVwn9ocRqn05RNfwtkQ
# 4   Ben and Jerry's    WI  ChIJsXbbrpBMs1IRfPAvDcUS-5A
# 5   Ben and Jerry's    WI  ChIJTf6LlDdTBogRqnX7ZSx0Q34
# 6   Ben and Jerry's    WI  ChIJq1EIiLRVBogRkeG32YbHpKA
# 7   Ben and Jerry's    WI  ChIJY5tIn_lgBYgRNiidII2WZrU
# 0   Ben and Jerry's    WY  ChIJfVoOLl0aU1MRggLaaAGJgBA
#
#                                    name  \
# 0                         Ben & Jerry's
# 1                         Ben & Jerry’s
# 2                   Mac & Jerry's Diner
# 3         Mike & Jerry's Paint & Supply
# 4            Jerry & Bill's Barber Shop
# 5                         Ben & Jerry’s
# 6                         Ben & Jerry's
# 0                         Ben & Jerry's
# 1              Dreyer's Grand Ice Cream
# 2   arizona select ice cream & candy co
# 3                         Ben & Jerry's
# 4                         Ben & Jerry's
# 5                         Ben & Jerry's
# 6                         Ben & Jerry's
# 0                         Ben & Jerry’s
# 0                         Ben & Jerry’s
# 1                         Ben & Jerry's
# 2                         Ben & Jerry’s
# 3                         Ben & Jerry's
# 4                         Ben & Jerry’s
# 5                         Ben & Jerry's
# 6                         Ben & Jerry's
# 7                         Ben & Jerry’s
# 8                         Ben & Jerry's
# 9                         Ben & Jerry's
# 10                        Ben & Jerry's
# 11                        Ben & Jerry's
# 12                        Ben & Jerry’s
# 13                        Ben & Jerry's
# 14                        Ben & Jerry's
# ..                                  ...
# 2                         Ben & Jerry’s
# 3                         Ben & Jerry's
# 0                         Ben & Jerry's
# 1                         Ben & Jerry's
# 2                         Ben & Jerry’s
# 3                         Ben & Jerry's
# 4                         Ben & Jerry's
# 5                         Ben & Jerry's
# 6                         Ben & Jerry's
# 7                         Ben & Jerry's
# 8                         Ben & Jerry's
# 9                         Ben & Jerry's
# 10                        Ben & Jerry's
# 11                        Ben & Jerry's
# 12                        Ben & Jerry’s
# 0                         Ben & Jerry's
# 1                         Ben & Jerry's
# 2                         Ben & Jerry's
# 3                         Ben & Jerry's
# 0                         Ben & Jerry's
# 1                         Ben & Jerry's
# 0                         Ben & Jerry's
# 1                         Ben & Jerry's
# 2               Tom & Jerry's Mini Golf
# 3                         Ben & Jerry’s
# 4                         Ben & Jerry’s
# 5                         Ben & Jerry's
# 6                         Ben & Jerry's
# 7                         Ben & Jerry's
# 0               Moo's Gourmet Ice Cream
#
#                                               address   latitude   longitude
# 0       150 Tom Hall Parkway, LaGrange, GA 30240, USA  32.992781  -85.026658
# 1            201 Broad St, Chattanooga, TN 37402, USA  35.054613  -85.311059
# 2             22585 AL-59, Robertsdale, AL 36567, USA  30.553893  -87.710445
# 3              748 Lakeside Dr, Mobile, AL 36693, USA  30.656607  -88.128340
# 4     2318 Governors Dr SW, Huntsville, AL 35805, USA  34.720841  -86.597564
# 5   9375 Emerald Coast Pkwy, Miramar Beach, FL 325...  30.377431  -86.332483
# 6   2801 Memorial Pkwy SW #80, Huntsville, AL 3580...  34.708386  -86.588053
# 0      2225 Village Walk Dr, Henderson, NV 89052, USA  36.021244 -115.085825
# 1          3337 W Wilshire Dr, Phoenix, AZ 85009, USA  33.475795 -112.130550
# 2         7150 W Roosevelt St, Phoenix, AZ 85043, USA  33.461087 -112.214399
# 3          1301 W Sunset Rd, Henderson, NV 89014, USA  36.060810 -115.040795
# 4   3627 S Las Vegas Blvd Suite 900, Las Vegas, NV...  36.114248 -115.172491
# 5   3663 S Las Vegas Blvd Suite #520, Las Vegas, N...  36.108740 -115.169815
# 6    34505 N Scottsdale Rd, Scottsdale, AZ 85266, USA  33.798104 -111.926977
# 0     5007 Black Rd Space 110, Memphis, TN 38117, USA  35.114362  -89.895088
# 0         7559 Carson Blvd, Long Beach, CA 90808, USA  33.829951 -118.086639
# 1   2130 Center St Suite 102, Berkeley, CA 94704, USA  37.870312 -122.267066
# 2                   1136 Main St, Napa, CA 94559, USA  38.300324 -122.286202
# 3                2459 Park Ave, Tustin, CA 92782, USA  33.696839 -117.828567
# 4        1480 Haight St, San Francisco, CA 94117, USA  37.770158 -122.446810
# 5        800 N Alameda St, Los Angeles, CA 90012, USA  34.055796 -118.235834
# 6      170 O'Farrell St, San Francisco, CA 94102, USA  37.787206 -122.407391
# 7   100 Universal City Plaza Space #151, Universal...  34.136392 -118.354518
# 8      9301 Tampa Ave #121, Northridge, CA 91324, USA  34.239356 -118.555757
# 9   71800 CA-111 Unit A-124, Rancho Mirage, CA 922...  33.739920 -116.409139
# 10              523 E Main St, Ventura, CA 93001, USA  34.280975 -119.292491
# 11  15301 Ventura Blvd Space P-6, Sherman Oaks, CA...  34.154921 -118.466828
# 12  6081 Center Dr Space 208, Los Angeles, CA 9004...  33.978025 -118.391332
# 13  110 S Palm Canyon Dr, Palm Springs, CA 92264, USA  33.822718 -116.546639
# 14  23630-D Valencia Boulevard, Creekside Rd, Vale...  34.416292 -118.548437
# ..                                                ...        ...         ...
# 2             454 Depot St, Manchester, VT 05255, USA  43.173276  -73.049406
# 3          24 Morse Dr, Jeffersonville, VT 05464, USA  44.588689  -72.787628
# 0    2510 Atlantic Ave, Virginia Beach, VA 23451, USA  36.854054  -75.976956
# 1    1116 Atlantic Ave, Virginia Beach, VA 23451, USA  36.840171  -75.973130
# 2           103 S Union St, Alexandria, VA 22314, USA  38.804025  -77.040507
# 3   4205 Fairfax Corner E Ave, Fairfax, VA 22033, USA  38.858604  -77.355992
# 4     1112 Emmet St N, Charlottesville, VA 22903, USA  38.051363  -78.501147
# 5    3220 Atlantic Ave, Virginia Beach, VA 23451, USA  36.861003  -75.978939
# 6              11916 Market St, Reston, VA 20190, USA  38.958856  -77.357809
# 7      21100 Dulles Town Cir, Sterling, VA 20166, USA  39.032412  -77.423638
# 8   4802 Valley View Boulevard NW Space LB-95, Roa...  37.303866  -79.963455
# 9    312 Sandbridge Rd, Virginia Beach, VA 23456, USA  36.746044  -75.946365
# 10    782 New River Rd, Christiansburg, VA 24073, USA  37.165158  -80.426826
# 11  5699 Richmond Rd #18, Williamsburg, VA 23188, USA  37.318575  -76.735899
# 12   332 Water St Building L, Yorktown, VA 23690, USA  37.238193  -76.508656
# 0   Shop 11/1-13 South Terrace, Fremantle WA 6160,... -32.055591  115.747043
# 1   Shop 30/58 Southside Dr, Sorrento WA 6025, Aus... -31.824739  115.739782
# 2         82 James St, Northbridge WA 6003, Australia -31.948628  115.858689
# 3   Lakeside Joondalup Shopping Centre (Ground flo... -31.743813  115.767212
# 0     782 New River Rd, Christiansburg, VA 24073, USA  37.165158  -80.426826
# 1      21100 Dulles Town Cir, Sterling, VA 20166, USA  39.032412  -77.423638
# 0              1860 Tower Dr, Glenview, IL 60026, USA  42.088593  -87.824466
# 1             600 E Grand Ave, Chicago, IL 60611, USA  41.891728  -87.608569
# 2              110 Suhrke Rd, Plymouth, WI 53073, USA  43.757031  -87.982715
# 3     3070 Excelsior Blvd, Minneapolis, MN 55416, USA  44.946926  -93.322359
# 4     539 Lake St E 1st Floor, Wayzata, MN 55391, USA  44.969865  -93.513705
# 5                224 State St, Madison, WI 53703, USA  43.074920  -89.388394
# 6       4000 International Ln, Madison, WI 53704, USA  43.136059  -89.345668
# 7           6610 Green Bay Rd, Kenosha, WI 53142, USA  42.574507  -87.886753
# 0               155 Center St, Jackson, WY 83001, USA  43.480412 -110.761127
#
# [247 rows x 7 columns]

# %%
clean_df= icecream_df[icecream_df.name.str.contains("Ben & Jerry's") == True]
clean_df2 = clean_df[clean_df.name.str.contains("Ben & Jerry's Catering CT") == False]
clean_df2.head()
# Out:
#              store state                     place_id           name  \
# 0  Ben and Jerry's    AL  ChIJkardCvVXi4gRFHu9ZF7L6AU  Ben & Jerry's
# 6  Ben and Jerry's    AL  ChIJGXOkbrZsYogR4I5fR5x5HH8  Ben & Jerry's
# 0  Ben and Jerry's    AZ  ChIJNRRNoN3RyIAR8-HZluDBkxU  Ben & Jerry's
# 3  Ben and Jerry's    AZ  ChIJTRJlLPHQyIAR5THux6fPoDQ  Ben & Jerry's
# 4  Ben and Jerry's    AZ  ChIJ7ZRhFTrEyIARn1A0skICWiQ  Ben & Jerry's
#
#                                              address   latitude   longitude
# 0      150 Tom Hall Parkway, LaGrange, GA 30240, USA  32.992781  -85.026658
# 6  2801 Memorial Pkwy SW #80, Huntsville, AL 3580...  34.708386  -86.588053
# 0     2225 Village Walk Dr, Henderson, NV 89052, USA  36.021244 -115.085825
# 3         1301 W Sunset Rd, Henderson, NV 89014, USA  36.060810 -115.040795
# 4  3627 S Las Vegas Blvd Suite 900, Las Vegas, NV...  36.114248 -115.172491

# %%
# write output to CSV file
clean_df2.to_csv(csv_file, index=False, quoting=csv.QUOTE_ALL)

# %%
import csv, json
import geojson
from geojson import Feature, FeatureCollection, Point, dump
import pandas as pd
icecream = pd.read_csv(r'ben&jerrys.geo-loc.2018-10-29-09.31.19.csv')
icecream.tail()
# Out:
#                store state                     place_id           name  \
# 144  Ben and Jerry's    WI  ChIJJyGFwK_HD4gRtZUkmFN3zk8  Ben & Jerry's
# 145  Ben and Jerry's    WI  ChIJj3c_ZFIrDogR4OxvPsmW4C8  Ben & Jerry's
# 146  Ben and Jerry's    WI  ChIJTf6LlDdTBogRqnX7ZSx0Q34  Ben & Jerry's
# 147  Ben and Jerry's    WI  ChIJq1EIiLRVBogRkeG32YbHpKA  Ben & Jerry's
# 148  Ben and Jerry's    WI  ChIJY5tIn_lgBYgRNiidII2WZrU  Ben & Jerry's
#
#                                            address   latitude  longitude
# 144         1860 Tower Dr, Glenview, IL 60026, USA  42.088593 -87.824466
# 145        600 E Grand Ave, Chicago, IL 60611, USA  41.891728 -87.608569
# 146           224 State St, Madison, WI 53703, USA  43.074920 -89.388394
# 147  4000 International Ln, Madison, WI 53704, USA  43.136059 -89.345668
# 148      6610 Green Bay Rd, Kenosha, WI 53142, USA  42.574507 -87.886753

# %%
def icecream_to_geojson(ufo, properties, latitude='latitude', longitude='longitude'):
    """
    Turn a dataframe containing point data into a geojson formatted python dictionary

    df : the dataframe to convert to geojson
    properties : a list of columns in the dataframe to turn into geojson feature properties
    lat : the name of the column in the dataframe that contains latitude data
    lng : the name of the column in the dataframe that contains longitude data
    """

    # create a new python dict to contain our geojson data, using geojson format
    geojson = {'type':'FeatureCollection', 'features':[]}

    # loop through each row in the dataframe and convert each row to geojson format
    # x is the equivalent of the row, df.iterrows converts the dataframe in to a pd.series object
    # the x is a counter and has no influence
    for x, row in icecream.iterrows():

        feature = {'type':'Feature',
                   'properties':{},
                   'geometry':{'type':'Point',
                               'coordinates':[]}}

        # fill in the coordinates
        feature['geometry']['coordinates'] = [float(row.longitude),float(row.latitude)]

        # be aware that the dataframe is a pd.series
        #print('rowitem converts to ndarray(numpy) :\n ', row)
        # convert the array to a pandas.serie
        geo_props = pd.Series(row)

        # for each column, get the value and add it as a new feature property
        # prop determines the list from the properties
        for prop in properties:

            #loop over the items to convert to string elements

            #convert to string
            if type(geo_props[prop]) == float:
                #print('ok')
                geo_props[prop] = str(int(geo_props[prop]))

            # now create a json format, here we have to make the dict properties
            feature['properties'][prop] = geo_props[prop]

        # add this feature (aka, converted dataframe row) to the list of features inside our dict
        geojson['features'].append(feature)
        
    return geojson

with open('icecream.geojson','w') as f:
    json.dump(icecream_to_geojson(icecream,['latitude','longitude']),f)
